# %% [markdown]
# # Velocity Test using the VR solver
#
# This testing procedure uses the velocity solver routine. It performs a simple t-Test on the calculated velocities.
#
# This notebook provides two ways to run:
#
# - Load data generated in a previous run. This let's us check the accuracy. If a split should occur or not was verified visually in a previous step.
# - Generating new data. A possible way of running through SigMA as a whole. However, we can not directly verify the accuracy this way.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pickle
import sys
from astropy.coordinates import SkyCoord, Galactic
import astropy.units as u
from scipy.stats import mode
from scipy.stats import ttest_ind
from calculate_velocity import calculate_velocity


sys.path.append('/home/nico/VSCodeRepos/SigMA')
from SigMA.SigMA import SigMA

# %% [markdown]
# ## Simulated Data Loading
#
# This data was generated in a previous run. Alternatively new data can be generated below.

# %%
# load data, generated for visual data analysis; this also includes the true labels and the weights generated by SigMA
df = pd.read_csv('simulated_data/df.csv', index_col=0)

# load the splits; each key/value pair contains the iteration when the split happens (key) and the cluster labels (values)
splits = pickle.load(open('simulated_data/splits.pkl', 'rb'))

# contains the labels after each split of the data
split_labels = pd.read_csv('simulated_data/labels_iteration.csv', index_col=0)

# %% [markdown]
# ## Simulated Data Generation

# %%
# Courtesy of Sebastian Ratzenböck
fname = 'simulated_data/Simulated_clusters_labeled_Region0_run6.csv'

def load_alena_data(fname, n_samples=50_000, delta_perc=1, add_noise=True):
    df = pd.read_csv(fname, index_col=0)
    labels_true = df['label'].values
    cols2fit = ['ra', 'dec', 'parallax', 'pmra', 'pmdec']
    df = df.rename(columns={'plx': 'parallax'})[cols2fit]
    # Scaling functions
    sf = {
        'ra': 1/0.64,
        'dec': 1/0.65,
        'parallax': 1/0.15,
        'pmra': 1/0.49,
        'pmdec': 1/0.57      
    }
    for col in cols2fit:
        df[col] *= sf[col]

    # Add noise
    if add_noise:
        # Determine ranges
        ptp_data = df[cols2fit].max() - df[cols2fit].min()
        ranges = [
            (df[col].min() - ptp_data[col] * delta_perc, df[col].max() + ptp_data[col] * delta_perc) 
            for col in cols2fit
        ]
        # Create uniform noise
        noise = np.random.uniform(*zip(*ranges), (n_samples, len(cols2fit)))
        # Add noise to data
        df_fit_noise = pd.concat([df[cols2fit], pd.DataFrame(noise, columns=cols2fit)], ignore_index=True)
        labels_true = np.r_[labels_true, np.ones(n_samples) * -1].astype(int)
    
        return df_fit_noise, labels_true, cols2fit
    else:
        return df, labels_true, cols2fit
    
def add_rvs(df, labels, keep_fraction=0.3):
    groups_to_rvs = {
        -1: (0, 50),
        0: (20, 3),
        1: (15, 3),
        2: (25, 3),
        3: (23, 4),
        4: (30, 5),
        5: (15, 4)
    }
    for gi, (mu, sigma) in groups_to_rvs.items():
        df.loc[labels==gi, 'radial_velocity'] = np.random.normal(mu, sigma, size=np.sum(labels==gi))
        df.loc[labels==gi, 'radial_velocity_error'] = np.random.uniform(1, 5, size=np.sum(labels==gi))
        
    # Remove some of the data
    cut_drop = np.random.uniform(0, 1, size=df.shape[0]) < keep_fraction
    df.loc[cut_drop, 'radial_velocity'] = np.nan
    df.loc[cut_drop, 'radial_velocity_error'] = np.nan
    # Set pm errors
    df['pmra_error'] = 0.3
    df['pmdec_error'] = 0.3

    # Add UVW
    # SkyCoord, compute 3D velocities
    c = SkyCoord(
        ra=df['ra'].values * u.deg, 
        dec=df['dec'].values * u.deg, 
        distance=1000/df['parallax'].values * u.pc,
        pm_ra_cosdec=df['pmra'].values * u.mas/u.yr,
        pm_dec=df['pmdec'].values * u.mas/u.yr,
        radial_velocity=df['radial_velocity'].values * u.km/u.s
    )
    c = c.transform_to(Galactic())
    c.representation_type = 'cartesian'
    
    df['U'] = c.U.value
    df['V'] = c.V.value
    df['W'] = c.W.value

    return df

df, labels, cols2fit = load_alena_data(fname, n_samples=50_000, delta_perc=0.5, add_noise=True)
df = add_rvs(df, labels, keep_fraction=0.3)

# %% [markdown]
# ## Run Sigma & Test

# %%
# Courtesy of Sebastian Ratzenböck
# Run SigMA
sigma_kwargs = dict(
    cluster_features=cols2fit,
    scale_factors=None,
    # These are the default values and should be kept for now
    nb_resampling=0, max_knn_density=101,
    beta=0.99, knn_initcluster_graph=40,
    transform_function=None
)
clusterer = SigMA(data=df, **sigma_kwargs).fit(alpha=0.01, knn=15, bh_correction=True)

def produce_baseline(clusterer):
    _, p_values = clusterer.run_sigma(
        alpha=-np.inf, knn=15, return_pvalues=True
    )
    p_values = np.array(p_values)
    pv_sorted = np.sort(p_values[p_values < 0.05])
    # compute mid point between consecutive p-values
    mid_points = (pv_sorted[1:] + pv_sorted[:-1]) / 2
    # Compute vhat for first step
    clusterer.fit(alpha=0.05, knn=15, bh_correction=True)
    return mid_points, clusterer.labels_

mid_points, l0 = produce_baseline(clusterer)
# Out:
# Performing gradient ascend using a 15-NN density estimation.
# Updated significance threshold: 1.00e-05

# %%
# Mostly written by Sebastian Ratzenböck
import time

for alpha_i in mid_points:
    # fit clusterer to new alpha
    clusterer.fit(alpha=alpha_i, knn=15, bh_correction=False)
    l_i = clusterer.labels_ 
    new_clusters_id = list(set(l_i) - set(l0))

    if len(new_clusters_id) == 1: 
        # one new cluster was generated
        nc_id = new_clusters_id[0]
        part_of_old_cluster = mode(l0[l_i==nc_id], keepdims=False).mode
        print(f'New cluster: {nc_id} coming from {part_of_old_cluster}')
        
        # Compute new 3D velocities
        v_hat_i = []
        for cl_i in [part_of_old_cluster, nc_id]:
            begin = time.time()
            print('Computing velocity for cluster', cl_i)
            v_hat_i.append(
                calculate_velocity(
                    data=df.loc[l_i==cl_i],
                    rho=clusterer.weights_[l_i==cl_i]
                )
            )
            print(f'Finished Computation for cluster {cl_i} in {time.time()-begin} seconds')

        test_results = ttest_ind(v_hat_i[0], v_hat_i[1]).pvalue
        print(f'Test results: {test_results}')
        same_velo = test_results[0] > 0.05 and test_results[1] > 0.05 and test_results[2] > 0.05
        print(f'Velocity equality: {same_velo}')
        print(f'Done')
        
    elif len(new_clusters_id) > 1:
        print('More than one new cluster')
    else:
        print('No new cluster')

    l0 = np.copy(l_i)
    print('-------------------\n')
# Out:
# No new cluster
# -------------------
#
# New cluster: 753 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 1.0461673736572266 seconds
# Computing velocity for cluster 753
# Finished Computation for cluster 753 in 0.5833196640014648 seconds
# Test results: [2.63052388e-294 8.36175740e-131 4.99376987e-260]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 445 coming from 753
# Computing velocity for cluster 753
# Finished Computation for cluster 753 in 0.6717581748962402 seconds
# Computing velocity for cluster 445
# Finished Computation for cluster 445 in 0.7291834354400635 seconds
# Test results: [0.82063686 0.64267368 0.94262779]
# Velocity equality: True
# Done
# -------------------
#
# New cluster: 8447 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 1.0951950550079346 seconds
# Computing velocity for cluster 8447
# Finished Computation for cluster 8447 in 0.7429928779602051 seconds
# Test results: [4.71754991e-09 9.27512771e-01 1.70007470e-64]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 39168 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 1.2256383895874023 seconds
# Computing velocity for cluster 39168
# Finished Computation for cluster 39168 in 0.44001340866088867 seconds
# Test results: [1.52417370e-082 3.27180941e-102 1.84532886e-140]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 13982 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 1.22025728225708 seconds
# Computing velocity for cluster 13982
# Finished Computation for cluster 13982 in 0.4598057270050049 seconds
# Test results: [1.28828001e-33 5.60365666e-36 2.15706957e-04]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 56394 coming from 445
# Computing velocity for cluster 445
# Finished Computation for cluster 445 in 0.776118278503418 seconds
# Computing velocity for cluster 56394
# Finished Computation for cluster 56394 in 0.48044681549072266 seconds
# Test results: [0.00031833 0.00363479 0.08912542]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 19072 coming from 8447
# Computing velocity for cluster 8447
# Finished Computation for cluster 8447 in 0.5839300155639648 seconds
# Computing velocity for cluster 19072
# Finished Computation for cluster 19072 in 0.6752786636352539 seconds
# Test results: [0.03894921 0.12779303 0.85977524]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 50885 coming from 8447
# Computing velocity for cluster 8447
# Finished Computation for cluster 8447 in 0.692145586013794 seconds
# Computing velocity for cluster 50885
# Finished Computation for cluster 50885 in 0.6737179756164551 seconds
# Test results: [2.50688688e-10 7.79992609e-11 3.42125114e-08]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 42958 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 1.2542340755462646 seconds
# Computing velocity for cluster 42958
# Finished Computation for cluster 42958 in 0.7171945571899414 seconds
# Test results: [0.47922213 0.81916079 0.00808792]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 1777 coming from 4137
# Computing velocity for cluster 4137
# Finished Computation for cluster 4137 in 0.8492724895477295 seconds
# Computing velocity for cluster 1777
# Finished Computation for cluster 1777 in 0.9512255191802979 seconds
# Test results: [0.0016262  0.55995659 0.48170398]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 16211 coming from 1777
# Computing velocity for cluster 1777
# Finished Computation for cluster 1777 in 0.9657766819000244 seconds
# Computing velocity for cluster 16211
# Finished Computation for cluster 16211 in 0.5638506412506104 seconds
# Test results: [1.40536071e-38 3.05384848e-58 1.88972079e-57]
# Velocity equality: False
# Done
# -------------------
#
# No new cluster
# -------------------
#
# New cluster: 39108 coming from 8540
# Computing velocity for cluster 8540
# Finished Computation for cluster 8540 in 0.4682488441467285 seconds
# Computing velocity for cluster 39108
# Finished Computation for cluster 39108 in 0.6736774444580078 seconds
# Test results: [0.02469789 0.13394887 0.02042182]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 41243 coming from 1777
# Computing velocity for cluster 1777
# Finished Computation for cluster 1777 in 0.9591810703277588 seconds
# Computing velocity for cluster 41243
# Finished Computation for cluster 41243 in 0.8209652900695801 seconds
# Test results: [0.03014171 0.00083929 0.05090375]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 28780 coming from 445
# Computing velocity for cluster 445
# Finished Computation for cluster 445 in 0.7321469783782959 seconds
# Computing velocity for cluster 28780
# Finished Computation for cluster 28780 in 0.3233675956726074 seconds
# Test results: [1.53757376e-12 1.03795694e-10 1.16116098e-06]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 37467 coming from 39168
# Computing velocity for cluster 39168
# Finished Computation for cluster 39168 in 0.32723474502563477 seconds
# Computing velocity for cluster 37467
# Finished Computation for cluster 37467 in 0.4310925006866455 seconds
# Test results: [0.35137229 0.77024126 0.62103265]
# Velocity equality: True
# Done
# -------------------
#
# New cluster: 53914 coming from 8447
# Computing velocity for cluster 8447
# Finished Computation for cluster 8447 in 0.7938482761383057 seconds
# Computing velocity for cluster 53914
# Finished Computation for cluster 53914 in 0.9832758903503418 seconds
# Test results: [1.66229145e-28 6.17938085e-24 1.33311691e-15]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 45837 coming from 1777
# Computing velocity for cluster 1777
# Finished Computation for cluster 1777 in 0.8583126068115234 seconds
# Computing velocity for cluster 45837
# Finished Computation for cluster 45837 in 0.6106116771697998 seconds
# Test results: [9.49460678e-87 1.40701622e-38 1.09672833e-87]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 34072 coming from 1777
# Computing velocity for cluster 1777
# Finished Computation for cluster 1777 in 0.851254940032959 seconds
# Computing velocity for cluster 34072
# Finished Computation for cluster 34072 in 0.9092283248901367 seconds
# Test results: [1.25730745e-07 5.31239684e-05 1.90186171e-06]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 56673 coming from 28780
# Computing velocity for cluster 28780
# Finished Computation for cluster 28780 in 0.3592102527618408 seconds
# Computing velocity for cluster 56673
# Finished Computation for cluster 56673 in 0.6784758567810059 seconds
# Test results: [9.18767597e-05 2.04652348e-03 6.72172417e-03]
# Velocity equality: False
# Done
# -------------------
#
# New cluster: 9519 coming from 8540
# Computing velocity for cluster 8540
# Finished Computation for cluster 8540 in 0.4643840789794922 seconds
# Computing velocity for cluster 9519
# Finished Computation for cluster 9519 in 0.7878024578094482 seconds
# Test results: [0.10765619 0.48950046 0.11313427]
# Velocity equality: True
# Done
# -------------------

# %% [markdown]
# ## Testing Procedure

# %%
correct_splits = 0
uvw = []
for iteration, cluster_labels in splits.items():
    print(f'--- Split of clusters {cluster_labels[0], cluster_labels[1]}---')
    # print(iteration, cluster_labels)
    # we need the data of the iteration and the weights
    uvw_cluster = []
    for cluster in cluster_labels[:2]:
        cluster_points = df[split_labels[iteration] == cluster]
        weights = df[split_labels[iteration] == cluster]['weights']
        
        uvw_cluster.append(calculate_velocity(cluster_points, weights))
    uvw.append(uvw_cluster)

    test_results = ttest_ind(uvw_cluster[0], uvw_cluster[1]).pvalue
    print(f'Test results: {test_results}')
    same_velo = test_results[0] > 0.05 and test_results[1] > 0.05 and test_results[2] > 0.05
    print(f'Velocity equality: {same_velo}')
    print(f'Should split: {"True" if cluster_labels[2] else "False"}\n')
    if same_velo != cluster_labels[2]:
        correct_splits += 1

print(f'{correct_splits} out of {len(splits)} were performed correctly')
# Out:
# --- Split of clusters (4137, 753)---
# Test results: [1.57989464e-223 1.22514589e-105 2.76051031e-208]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (753, 445)---
# Test results: [1.57451876e-02 7.57170035e-13 7.07218368e-03]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 8447)---
# Test results: [1.05130797e-13 1.28806778e-01 1.00240851e-61]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8447, 36243)---
# Test results: [2.40205044e-26 6.50704881e-29 3.39979140e-23]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 22941)---
# Test results: [2.11290488e-69 1.66484340e-65 1.71836023e-74]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 32730)---
# Test results: [2.97203186e-10 1.46927112e-18 1.02251576e-22]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (753, 48293)---
# Test results: [1.42545837e-07 3.65545055e-09 1.20723356e-09]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 48034)---
# Test results: [7.18696178e-26 2.71754816e-35 1.19572239e-23]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8540, 52908)---
# Test results: [0.22503522 0.16623094 0.13642051]
# Velocity equality: True
# Should split: True
#
# --- Split of clusters (4137, 1777)---
# Test results: [4.07038086e-07 1.40098128e-01 5.57723535e-03]
# Velocity equality: False
# Should split: False
#
# --- Split of clusters (4137, 58479)---
# Test results: [1.60102309e-44 6.50019238e-41 6.93954349e-45]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8447, 51699)---
# Test results: [5.33634375e-09 1.27402930e-04 4.41107807e-06]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 35983)---
# Test results: [2.11020858e-42 1.75815033e-20 5.34169211e-56]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (1777, 43389)---
# Test results: [7.28399063e-31 1.29542128e-32 9.28393853e-13]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8447, 50397)---
# Test results: [1.56611208e-08 9.94894253e-09 5.31550448e-09]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8447, 51478)---
# Test results: [3.68381138e-07 7.87942511e-07 2.25646654e-09]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (1777, 24290)---
# Test results: [9.16103978e-20 3.77007569e-32 2.16430973e-85]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (4137, 38097)---
# Test results: [2.47922048e-24 2.83905078e-37 4.05667090e-29]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (1777, 34494)---
# Test results: [1.49254646e-51 5.96043634e-40 1.25443150e-60]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (1777, 44506)---
# Test results: [2.96247007e-82 1.66542496e-61 5.34929148e-93]
# Velocity equality: False
# Should split: True
#
# --- Split of clusters (8540, 27512)---
# Test results: [0.67220944 0.39948996 0.60480447]
# Velocity equality: True
# Should split: True
#
# --- Split of clusters (4137, 22511)---
# Test results: [3.95003090e-27 4.89923221e-28 2.16874040e-34]
# Velocity equality: False
# Should split: True
#
# 19 out of 22 were performed correctly
